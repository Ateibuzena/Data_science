# %% [markdown]
# ## Airtable
#
# **Airtable** es una plataforma online fácil de usar para crear y compartir bases de datos. La interfaz es sencilla, amigable y permite a cualquier persona crear una base de datos.
#
# _**Documentación:** https://airtable.com/developers/web/api/introduction_

# %%
import numpy as np
import pandas as pd

import requests

from pprint import pprint

# %% [markdown]
# #### Authentication - Tokens

# %%
def get_secrets(path:str)->dict:
    '''
    This functions receives a text file with the secrets of an API, and returns it
    '''
    with open (path, 'r') as file:
        secrets = file.read()
    credentials = (
        {
        secreto.split(' = ')[0]:secreto.split(' = ')[1] 
        for secreto in secrets.split('\n')
        }
    )
    
    return credentials

# %%
credentials = get_secrets('../Actividades/airtable_secrets.txt')
credentials
# Out:
# {'token2': 'patOLPpXmDmvhoZA9.bce5228a097ca82f33efdfea9bcbeb9b4d6cd83988e82b8ff5f7be7e26e7312e'}

# %%
API_KEY = credentials['token2'] # Usuario

BASE_ID = "appwVbYoCYZjw2K8u" # Base: Tabla API #entre la primera barra y la segunda

TABLE_ID = "tblkjGQCfG4dUSCon"# Tabla: datos_1 #entre la segunda y la tercera

airtable_base_url = "https://api.airtable.com/v0"

# %%
# Headers
headers = {"Authorization" : f"Bearer {API_KEY}",
           "Content-Type"  : "application/json"}

pprint(headers)
# Out:
# {'Authorization': 'Bearer '
#                   'patOLPpXmDmvhoZA9.bce5228a097ca82f33efdfea9bcbeb9b4d6cd83988e82b8ff5f7be7e26e7312e',
#  'Content-Type': 'application/json'}

# %% [markdown]
# ### 01. List Records
#
# ```html
# endpoint: https://api.airtable.com/v0/{BASE_ID}/{TABLE_ID}
# HTTP method: GET
# ```
#
# **`Params:`**
# - **fields** : _array of strings_ : `optional`
#     - Only data for fields whose names are in this list will be included in the result. If you don't need every field, you can use this parameter to reduce the amount of data transferred.
#
#
# - **filterByFormula** : _string_ : `optional`
#     - A [formula](https://support.airtable.com/docs/formula-field-reference) used to filter records. The formula will be evaluated for each record, and if the result is not 0, false, "", NaN, [], or #Error! the record will be included in the response. We recommend testing your formula in the Formula field UI before using it in your API request. If combined with the view parameter, only records in that view which satisfy the formula will be returned. The formula must be encoded first before passing it as a value. You can use this tool to not only encode the formula but also create the entire url you need.
#
#
# - **maxRecords** : _number_ : `optional`
#     - The maximum total number of records that will be returned in your requests. If this value is larger than pageSize (which is 100 by default), you may have to load multiple pages to reach this total.
#
#
# - **pageSize** : _number_ : `optional`
#     - The number of records returned in each request. Must be less than or equal to 100. Default is 100.
#
#
# - **sort** : _array of objects_ : `optional`
#     - A list of sort objects that specifies how the records will be ordered. Each sort object must have a field key specifying the name of the field to sort on, and an optional direction key that is either "asc" or "desc". The default direction is "asc". The sort parameter overrides the sorting of the view specified in the view parameter. If neither the sort nor the view parameter is included, the order of records is arbitrary.
#
#
#         - For example, to sort records by Name in descending order, send these two query parameters:
#             - sort%5B0%5D%5Bfield%5D=Name
#             - sort%5B0%5D%5Bdirection%5D=desc
#
#           For example, to sort records by Name in descending order, pass in:
#             - [{field: "Name", direction: "desc"}]
#
# - **cellFormat** : _string_ : `optional`
#     - The format that should be used for cell values. Supported values are:
#         - **json**: cells will be formatted as JSON, depending on the field type.
#         - **string**: cells will be formatted as user-facing strings, regardless of the field type. The **timeZone** and **userLocale** parameters are required when using string as the **cellFormat**.
#         - The default is **json**.
#
#
# - **timeZone** : _string_ : `optional`
#     - The time zone that should be used to format dates when using string as the **cellFormat**. This parameter is required when using string as the **cellFormat**.
#
#
# - **userLocale** : _string_ : `optional`
#     - The user locale that should be used to format dates when using string as the **cellFormat**. This parameter is required when using string as the **cellFormat**.
#
#
# - **returnFieldsByFieldId** : _boolean_ : `optional`
#     - An optional boolean value that lets you return field objects where the key is the field id.
#     - his defaults to **false**, which returns field objects where the key is the field name.

# %%
# List Records

# Endpoint
endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}"

params = {"fields"                : None, 
          "maxRecords"            : None, 
          "pageSize"              : None,
          "returnFieldsByFieldId" : False}

print(endpoint)

pprint(params, sort_dicts = False)
# Out:
# https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon
# {'fields': None,
#  'maxRecords': None,
#  'pageSize': None,
#  'returnFieldsByFieldId': False}

# %%
response = requests.get(url = endpoint, headers = headers, params = params)

print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = False)

print("-"*120)

records_id = [x["id"] for x in response.json()["records"]]
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?returnFieldsByFieldId=False
# ------------------------------------------------------------------------------------------------------------------------
# {'records': [{'id': 'rec024U5m04leThgR',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Buneary',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 44,
#                          '#': 427,
#                          'Generation': 4,
#                          'Attack': 66,
#                          'Defense': 44,
#                          'Total': 350,
#                          'Sp. Def': 56,
#                          'HP': 55,
#                          'Speed': 85}},
#              {'id': 'rec02nAj8FEGimqIo',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Alomomola',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 40,
#                          '#': 594,
#                          'Generation': 5,
#                          'Attack': 75,
#                          'Defense': 80,
#                          'Total': 470,
#                          'Sp. Def': 45,
#                          'HP': 165,
#                          'Speed': 65}},
#              {'id': 'rec0FaekQXOmqm43r',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Rotom',
#                          'Type 2': 'Ghost',
#                          'Type 1': 'Electric',
#                          'Sp. Atk': 95,
#                          '#': 479,
#                          'Generation': 4,
#                          'Attack': 50,
#                          'Defense': 77,
#                          'Total': 440,
#                          'Sp. Def': 77,
#                          'HP': 50,
#                          'Speed': 91}},
#              {'id': 'rec0K6M4Pb8fiA7mv',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Grotle',
#                          'Type 1': 'Grass',
#                          'Sp. Atk': 55,
#                          '#': 388,
#                          'Generation': 4,
#                          'Attack': 89,
#                          'Defense': 85,
#                          'Total': 405,
#                          'Sp. Def': 65,
#                          'HP': 75,
#                          'Speed': 36}},
#              {'id': 'rec0KQmVKYKrAutqz',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Pyroar',
#                          'Type 2': 'Normal',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 109,
#                          '#': 668,
#                          'Generation': 6,
#                          'Attack': 68,
#                          'Defense': 72,
#                          'Total': 507,
#                          'Sp. Def': 66,
#                          'HP': 86,
#                          'Speed': 106}},
#              {'id': 'rec0YbfJ3d2dejn92',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Beartic',
#                          'Type 1': 'Ice',
#                          'Sp. Atk': 70,
#                          '#': 614,
#                          'Generation': 5,
#                          'Attack': 110,
#                          'Defense': 80,
#                          'Total': 485,
#                          'Sp. Def': 80,
#                          'HP': 95,
#                          'Speed': 50}},
#              {'id': 'rec0cMIc3lHMJdOK5',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Yanmega',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 116,
#                          '#': 469,
#                          'Generation': 4,
#                          'Attack': 76,
#                          'Defense': 86,
#                          'Total': 515,
#                          'Sp. Def': 56,
#                          'HP': 86,
#                          'Speed': 95}},
#              {'id': 'rec0dOOELRdXXTlWY',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Noctowl',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 76,
#                          '#': 164,
#                          'Generation': 2,
#                          'Attack': 50,
#                          'Defense': 50,
#                          'Total': 442,
#                          'Sp. Def': 96,
#                          'HP': 100,
#                          'Speed': 70}},
#              {'id': 'rec0hznr3w1jk2vMh',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'Rayquaza',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Dragon',
#                          'Sp. Atk': 150,
#                          '#': 384,
#                          'Generation': 3,
#                          'Attack': 150,
#                          'Defense': 90,
#                          'Total': 680,
#                          'Sp. Def': 90,
#                          'HP': 105,
#                          'Speed': 95}},
#              {'id': 'rec0kU4DCB35N9HD2',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Duosion',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 125,
#                          '#': 578,
#                          'Generation': 5,
#                          'Attack': 40,
#                          'Defense': 50,
#                          'Total': 370,
#                          'Sp. Def': 60,
#                          'HP': 65,
#                          'Speed': 30}},
#              {'id': 'rec0oVF8wrQkT3tHy',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Poochyena',
#                          'Type 1': 'Dark',
#                          'Sp. Atk': 30,
#                          '#': 261,
#                          'Generation': 3,
#                          'Attack': 55,
#                          'Defense': 35,
#                          'Total': 220,
#                          'Sp. Def': 30,
#                          'HP': 35,
#                          'Speed': 35}},
#              {'id': 'rec0rMrberGHuLwVV',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Skarmory',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Steel',
#                          'Sp. Atk': 40,
#                          '#': 227,
#                          'Generation': 2,
#                          'Attack': 80,
#                          'Defense': 140,
#                          'Total': 465,
#                          'Sp. Def': 70,
#                          'HP': 65,
#                          'Speed': 70}},
#              {'id': 'rec0w02diRXOqVrPY',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Growlithe',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 70,
#                          '#': 58,
#                          'Generation': 1,
#                          'Attack': 70,
#                          'Defense': 45,
#                          'Total': 350,
#                          'Sp. Def': 50,
#                          'HP': 55,
#                          'Speed': 60}},
#              {'id': 'rec12SgksrLd36rqY',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'SwampertMega Swampert',
#                          'Type 2': 'Ground',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 95,
#                          '#': 260,
#                          'Generation': 3,
#                          'Attack': 150,
#                          'Defense': 110,
#                          'Total': 635,
#                          'Sp. Def': 110,
#                          'HP': 100,
#                          'Speed': 70}},
#              {'id': 'rec12abgTdHHSlWn7',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Scyther',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 55,
#                          '#': 123,
#                          'Generation': 1,
#                          'Attack': 110,
#                          'Defense': 80,
#                          'Total': 500,
#                          'Sp. Def': 80,
#                          'HP': 70,
#                          'Speed': 105}},
#              {'id': 'rec16LhpOs4sDO3nb',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Delcatty',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 55,
#                          '#': 301,
#                          'Generation': 3,
#                          'Attack': 65,
#                          'Defense': 65,
#                          'Total': 380,
#                          'Sp. Def': 55,
#                          'HP': 70,
#                          'Speed': 70}},
#              {'id': 'rec17USZ2YCFT8Dc5',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Cubchoo',
#                          'Type 1': 'Ice',
#                          'Sp. Atk': 60,
#                          '#': 613,
#                          'Generation': 5,
#                          'Attack': 70,
#                          'Defense': 40,
#                          'Total': 305,
#                          'Sp. Def': 40,
#                          'HP': 55,
#                          'Speed': 40}},
#              {'id': 'rec19CW8nfBsFNfga',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Braviary',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 57,
#                          '#': 628,
#                          'Generation': 5,
#                          'Attack': 123,
#                          'Defense': 75,
#                          'Total': 510,
#                          'Sp. Def': 75,
#                          'HP': 100,
#                          'Speed': 80}},
#              {'id': 'rec1DIUqtbSfQ0b2l',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Porygon',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 85,
#                          '#': 137,
#                          'Generation': 1,
#                          'Attack': 60,
#                          'Defense': 70,
#                          'Total': 395,
#                          'Sp. Def': 75,
#                          'HP': 65,
#                          'Speed': 40}},
#              {'id': 'rec1IEc9tKckPURVY',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'Raikou',
#                          'Type 1': 'Electric',
#                          'Sp. Atk': 115,
#                          '#': 243,
#                          'Generation': 2,
#                          'Attack': 85,
#                          'Defense': 75,
#                          'Total': 580,
#                          'Sp. Def': 100,
#                          'HP': 90,
#                          'Speed': 115}},
#              {'id': 'rec1LhHk3SITAJfXK',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Aggron',
#                          'Type 2': 'Rock',
#                          'Type 1': 'Steel',
#                          'Sp. Atk': 60,
#                          '#': 306,
#                          'Generation': 3,
#                          'Attack': 110,
#                          'Defense': 180,
#                          'Total': 530,
#                          'Sp. Def': 60,
#                          'HP': 70,
#                          'Speed': 50}},
#              {'id': 'rec1WLUsOksHMa0u7',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Shuckle',
#                          'Type 2': 'Rock',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 10,
#                          '#': 213,
#                          'Generation': 2,
#                          'Attack': 10,
#                          'Defense': 230,
#                          'Total': 505,
#                          'Sp. Def': 230,
#                          'HP': 20,
#                          'Speed': 5}},
#              {'id': 'rec1XBapUx5DCWQdd',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Whismur',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 51,
#                          '#': 293,
#                          'Generation': 3,
#                          'Attack': 51,
#                          'Defense': 23,
#                          'Total': 240,
#                          'Sp. Def': 23,
#                          'HP': 64,
#                          'Speed': 28}},
#              {'id': 'rec1g1yYOoi3RBTzW',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Spinarak',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 40,
#                          '#': 167,
#                          'Generation': 2,
#                          'Attack': 60,
#                          'Defense': 40,
#                          'Total': 250,
#                          'Sp. Def': 40,
#                          'HP': 40,
#                          'Speed': 30}},
#              {'id': 'rec1hQPhSreJnSrjk',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Bibarel',
#                          'Type 2': 'Water',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 55,
#                          '#': 400,
#                          'Generation': 4,
#                          'Attack': 85,
#                          'Defense': 60,
#                          'Total': 410,
#                          'Sp. Def': 60,
#                          'HP': 79,
#                          'Speed': 71}},
#              {'id': 'rec1hTaEZpTi8l0bF',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Tangela',
#                          'Type 1': 'Grass',
#                          'Sp. Atk': 100,
#                          '#': 114,
#                          'Generation': 1,
#                          'Attack': 55,
#                          'Defense': 115,
#                          'Total': 435,
#                          'Sp. Def': 40,
#                          'HP': 65,
#                          'Speed': 60}},
#              {'id': 'rec1hhLJG2uvzRXi6',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Wooper',
#                          'Type 2': 'Ground',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 25,
#                          '#': 194,
#                          'Generation': 2,
#                          'Attack': 45,
#                          'Defense': 45,
#                          'Total': 210,
#                          'Sp. Def': 25,
#                          'HP': 55,
#                          'Speed': 15}},
#              {'id': 'rec1wZyUrcobM2veI',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Accelgor',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 100,
#                          '#': 617,
#                          'Generation': 5,
#                          'Attack': 70,
#                          'Defense': 40,
#                          'Total': 495,
#                          'Sp. Def': 60,
#                          'HP': 80,
#                          'Speed': 145}},
#              {'id': 'rec25g7Tvgl83FxUG',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Vullaby',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Dark',
#                          'Sp. Atk': 45,
#                          '#': 629,
#                          'Generation': 5,
#                          'Attack': 55,
#                          'Defense': 75,
#                          'Total': 370,
#                          'Sp. Def': 65,
#                          'HP': 70,
#                          'Speed': 60}},
#              {'id': 'rec2DhrTIsNufQNRH',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Budew',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Grass',
#                          'Sp. Atk': 50,
#                          '#': 406,
#                          'Generation': 4,
#                          'Attack': 30,
#                          'Defense': 35,
#                          'Total': 280,
#                          'Sp. Def': 70,
#                          'HP': 40,
#                          'Speed': 55}},
#              {'id': 'rec2HhQIdKoHrCniB',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Krabby',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 25,
#                          '#': 98,
#                          'Generation': 1,
#                          'Attack': 105,
#                          'Defense': 90,
#                          'Total': 325,
#                          'Sp. Def': 25,
#                          'HP': 30,
#                          'Speed': 50}},
#              {'id': 'rec2KdJu1BD7rqcKk',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Quilladin',
#                          'Type 1': 'Grass',
#                          'Sp. Atk': 56,
#                          '#': 651,
#                          'Generation': 6,
#                          'Attack': 78,
#                          'Defense': 95,
#                          'Total': 405,
#                          'Sp. Def': 58,
#                          'HP': 61,
#                          'Speed': 57}},
#              {'id': 'rec2o905ev7IhoHuB',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Meowth',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 40,
#                          '#': 52,
#                          'Generation': 1,
#                          'Attack': 45,
#                          'Defense': 35,
#                          'Total': 290,
#                          'Sp. Def': 40,
#                          'HP': 40,
#                          'Speed': 90}},
#              {'id': 'rec2serVzfrxMnX3M',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Lillipup',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 25,
#                          '#': 506,
#                          'Generation': 5,
#                          'Attack': 60,
#                          'Defense': 45,
#                          'Total': 275,
#                          'Sp. Def': 45,
#                          'HP': 45,
#                          'Speed': 55}},
#              {'id': 'rec2tLnVoh2Ndcpxx',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Monferno',
#                          'Type 2': 'Fighting',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 78,
#                          '#': 391,
#                          'Generation': 4,
#                          'Attack': 78,
#                          'Defense': 52,
#                          'Total': 405,
#                          'Sp. Def': 52,
#                          'HP': 64,
#                          'Speed': 81}},
#              {'id': 'rec2yDdaOur9YBcXe',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Delibird',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Ice',
#                          'Sp. Atk': 65,
#                          '#': 225,
#                          'Generation': 2,
#                          'Attack': 55,
#                          'Defense': 45,
#                          'Total': 330,
#                          'Sp. Def': 45,
#                          'HP': 45,
#                          'Speed': 75}},
#              {'id': 'rec37FUE7ylmYlVQG',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Scizor',
#                          'Type 2': 'Steel',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 55,
#                          '#': 212,
#                          'Generation': 2,
#                          'Attack': 130,
#                          'Defense': 100,
#                          'Total': 500,
#                          'Sp. Def': 80,
#                          'HP': 70,
#                          'Speed': 65}},
#              {'id': 'rec3IQr50WYQCZ9p3',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Gastly',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Ghost',
#                          'Sp. Atk': 100,
#                          '#': 92,
#                          'Generation': 1,
#                          'Attack': 35,
#                          'Defense': 30,
#                          'Total': 310,
#                          'Sp. Def': 35,
#                          'HP': 30,
#                          'Speed': 80}},
#              {'id': 'rec3ITZAJXGHOytWd',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Whimsicott',
#                          'Type 2': 'Fairy',
#                          'Type 1': 'Grass',
#                          'Sp. Atk': 77,
#                          '#': 547,
#                          'Generation': 5,
#                          'Attack': 67,
#                          'Defense': 85,
#                          'Total': 480,
#                          'Sp. Def': 75,
#                          'HP': 60,
#                          'Speed': 116}},
#              {'id': 'rec3Os6BXdyHEdw2p',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Pineco',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 35,
#                          '#': 204,
#                          'Generation': 2,
#                          'Attack': 65,
#                          'Defense': 90,
#                          'Total': 290,
#                          'Sp. Def': 35,
#                          'HP': 50,
#                          'Speed': 15}},
#              {'id': 'rec3P8Q6WD7m6GJHa',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Chingling',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 65,
#                          '#': 433,
#                          'Generation': 4,
#                          'Attack': 30,
#                          'Defense': 50,
#                          'Total': 285,
#                          'Sp. Def': 50,
#                          'HP': 45,
#                          'Speed': 45}},
#              {'id': 'rec3Xl4K7Y0s044Py',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Garchomp',
#                          'Type 2': 'Ground',
#                          'Type 1': 'Dragon',
#                          'Sp. Atk': 80,
#                          '#': 445,
#                          'Generation': 4,
#                          'Attack': 130,
#                          'Defense': 95,
#                          'Total': 600,
#                          'Sp. Def': 85,
#                          'HP': 108,
#                          'Speed': 102}},
#              {'id': 'rec3apInrfEEeCYcE',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'ManectricMega Manectric',
#                          'Type 1': 'Electric',
#                          'Sp. Atk': 135,
#                          '#': 310,
#                          'Generation': 3,
#                          'Attack': 75,
#                          'Defense': 80,
#                          'Total': 575,
#                          'Sp. Def': 80,
#                          'HP': 70,
#                          'Speed': 135}},
#              {'id': 'rec3coqMrgybHU9x4',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Butterfree',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 90,
#                          '#': 12,
#                          'Generation': 1,
#                          'Attack': 45,
#                          'Defense': 50,
#                          'Total': 395,
#                          'Sp. Def': 80,
#                          'HP': 60,
#                          'Speed': 70}},
#              {'id': 'rec3iiHRYFmFfLIfi',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Mudkip',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 50,
#                          '#': 258,
#                          'Generation': 3,
#                          'Attack': 70,
#                          'Defense': 50,
#                          'Total': 310,
#                          'Sp. Def': 50,
#                          'HP': 50,
#                          'Speed': 40}},
#              {'id': 'rec3l0aE34fKNDGik',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Electivire',
#                          'Type 1': 'Electric',
#                          'Sp. Atk': 95,
#                          '#': 466,
#                          'Generation': 4,
#                          'Attack': 123,
#                          'Defense': 67,
#                          'Total': 540,
#                          'Sp. Def': 85,
#                          'HP': 75,
#                          'Speed': 95}},
#              {'id': 'rec3nx2qTl4F6O42d',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Dewgong',
#                          'Type 2': 'Ice',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 70,
#                          '#': 87,
#                          'Generation': 1,
#                          'Attack': 70,
#                          'Defense': 80,
#                          'Total': 475,
#                          'Sp. Def': 95,
#                          'HP': 90,
#                          'Speed': 70}},
#              {'id': 'rec3wF44V77lI8IlN',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Slaking',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 95,
#                          '#': 289,
#                          'Generation': 3,
#                          'Attack': 160,
#                          'Defense': 100,
#                          'Total': 670,
#                          'Sp. Def': 65,
#                          'HP': 150,
#                          'Speed': 100}},
#              {'id': 'rec3xhlzuGQVeOJDV',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Yanma',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 75,
#                          '#': 193,
#                          'Generation': 2,
#                          'Attack': 65,
#                          'Defense': 45,
#                          'Total': 390,
#                          'Sp. Def': 45,
#                          'HP': 65,
#                          'Speed': 95}},
#              {'id': 'rec3yk0e181ZWbykA',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Hitmontop',
#                          'Type 1': 'Fighting',
#                          'Sp. Atk': 35,
#                          '#': 237,
#                          'Generation': 2,
#                          'Attack': 95,
#                          'Defense': 95,
#                          'Total': 455,
#                          'Sp. Def': 110,
#                          'HP': 50,
#                          'Speed': 70}},
#              {'id': 'rec3yw77dvOd8LMvx',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'LandorusTherian Forme',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Ground',
#                          'Sp. Atk': 105,
#                          '#': 645,
#                          'Generation': 5,
#                          'Attack': 145,
#                          'Defense': 90,
#                          'Total': 600,
#                          'Sp. Def': 80,
#                          'HP': 89,
#                          'Speed': 91}},
#              {'id': 'rec41sQ9iCz5Owp3v',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Wingull',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 55,
#                          '#': 278,
#                          'Generation': 3,
#                          'Attack': 30,
#                          'Defense': 30,
#                          'Total': 270,
#                          'Sp. Def': 30,
#                          'HP': 40,
#                          'Speed': 85}},
#              {'id': 'rec43uI5sfTPHLDa7',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Mr. Mime',
#                          'Type 2': 'Fairy',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 100,
#                          '#': 122,
#                          'Generation': 1,
#                          'Attack': 45,
#                          'Defense': 65,
#                          'Total': 460,
#                          'Sp. Def': 120,
#                          'HP': 40,
#                          'Speed': 90}},
#              {'id': 'rec487e50KubCWDyf',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Hawlucha',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Fighting',
#                          'Sp. Atk': 74,
#                          '#': 701,
#                          'Generation': 6,
#                          'Attack': 92,
#                          'Defense': 75,
#                          'Total': 500,
#                          'Sp. Def': 63,
#                          'HP': 78,
#                          'Speed': 118}},
#              {'id': 'rec4BlzLUcBMxOzGw',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Wurmple',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 20,
#                          '#': 265,
#                          'Generation': 3,
#                          'Attack': 45,
#                          'Defense': 35,
#                          'Total': 195,
#                          'Sp. Def': 30,
#                          'HP': 45,
#                          'Speed': 20}},
#              {'id': 'rec4FMmx8yQWvCU3j',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Krookodile',
#                          'Type 2': 'Dark',
#                          'Type 1': 'Ground',
#                          'Sp. Atk': 65,
#                          '#': 553,
#                          'Generation': 5,
#                          'Attack': 117,
#                          'Defense': 80,
#                          'Total': 519,
#                          'Sp. Def': 70,
#                          'HP': 95,
#                          'Speed': 92}},
#              {'id': 'rec4WY0eHFuaHQT4f',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'AggronMega Aggron',
#                          'Type 1': 'Steel',
#                          'Sp. Atk': 60,
#                          '#': 306,
#                          'Generation': 3,
#                          'Attack': 140,
#                          'Defense': 230,
#                          'Total': 630,
#                          'Sp. Def': 80,
#                          'HP': 70,
#                          'Speed': 50}},
#              {'id': 'rec4ZK9fHhjgp8h6v',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Buizel',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 60,
#                          '#': 418,
#                          'Generation': 4,
#                          'Attack': 65,
#                          'Defense': 35,
#                          'Total': 330,
#                          'Sp. Def': 30,
#                          'HP': 55,
#                          'Speed': 85}},
#              {'id': 'rec4gtWPLotRKNgLY',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Slowbro',
#                          'Type 2': 'Psychic',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 100,
#                          '#': 80,
#                          'Generation': 1,
#                          'Attack': 75,
#                          'Defense': 110,
#                          'Total': 490,
#                          'Sp. Def': 80,
#                          'HP': 95,
#                          'Speed': 30}},
#              {'id': 'rec4gx3LXGyR6yjEr',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Clauncher',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 58,
#                          '#': 692,
#                          'Generation': 6,
#                          'Attack': 53,
#                          'Defense': 62,
#                          'Total': 330,
#                          'Sp. Def': 63,
#                          'HP': 50,
#                          'Speed': 44}},
#              {'id': 'rec4hdqjWxolM05Jm',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Venonat',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 40,
#                          '#': 48,
#                          'Generation': 1,
#                          'Attack': 55,
#                          'Defense': 50,
#                          'Total': 305,
#                          'Sp. Def': 55,
#                          'HP': 60,
#                          'Speed': 45}},
#              {'id': 'rec4i0grKLZaCbTDO',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Weedle',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 20,
#                          '#': 13,
#                          'Generation': 1,
#                          'Attack': 35,
#                          'Defense': 30,
#                          'Total': 195,
#                          'Sp. Def': 20,
#                          'HP': 40,
#                          'Speed': 50}},
#              {'id': 'rec4j5Bb8WfXpyWzo',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Torkoal',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 85,
#                          '#': 324,
#                          'Generation': 3,
#                          'Attack': 85,
#                          'Defense': 140,
#                          'Total': 470,
#                          'Sp. Def': 70,
#                          'HP': 70,
#                          'Speed': 20}},
#              {'id': 'rec4pHxhpAYNiaAob',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Malamar',
#                          'Type 2': 'Psychic',
#                          'Type 1': 'Dark',
#                          'Sp. Atk': 68,
#                          '#': 687,
#                          'Generation': 6,
#                          'Attack': 92,
#                          'Defense': 88,
#                          'Total': 482,
#                          'Sp. Def': 75,
#                          'HP': 86,
#                          'Speed': 73}},
#              {'id': 'rec4qqLldKUI3kWPb',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Cinccino',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 65,
#                          '#': 573,
#                          'Generation': 5,
#                          'Attack': 95,
#                          'Defense': 60,
#                          'Total': 470,
#                          'Sp. Def': 60,
#                          'HP': 75,
#                          'Speed': 115}},
#              {'id': 'rec51D1EAJq4W5KSl',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'Suicune',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 90,
#                          '#': 245,
#                          'Generation': 2,
#                          'Attack': 75,
#                          'Defense': 115,
#                          'Total': 580,
#                          'Sp. Def': 115,
#                          'HP': 100,
#                          'Speed': 85}},
#              {'id': 'rec59wZCRN3S2ojYM',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Lotad',
#                          'Type 2': 'Grass',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 40,
#                          '#': 270,
#                          'Generation': 3,
#                          'Attack': 30,
#                          'Defense': 30,
#                          'Total': 220,
#                          'Sp. Def': 50,
#                          'HP': 40,
#                          'Speed': 30}},
#              {'id': 'rec5AaGKmN0H86kpI',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Medicham',
#                          'Type 2': 'Psychic',
#                          'Type 1': 'Fighting',
#                          'Sp. Atk': 60,
#                          '#': 308,
#                          'Generation': 3,
#                          'Attack': 60,
#                          'Defense': 75,
#                          'Total': 410,
#                          'Sp. Def': 75,
#                          'HP': 60,
#                          'Speed': 80}},
#              {'id': 'rec5Ajv0vtv1w1Sw6',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Bagon',
#                          'Type 1': 'Dragon',
#                          'Sp. Atk': 40,
#                          '#': 371,
#                          'Generation': 3,
#                          'Attack': 75,
#                          'Defense': 60,
#                          'Total': 300,
#                          'Sp. Def': 30,
#                          'HP': 45,
#                          'Speed': 50}},
#              {'id': 'rec5QIM8DPz7KCNoO',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Marill',
#                          'Type 2': 'Fairy',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 20,
#                          '#': 183,
#                          'Generation': 2,
#                          'Attack': 20,
#                          'Defense': 50,
#                          'Total': 250,
#                          'Sp. Def': 50,
#                          'HP': 70,
#                          'Speed': 40}},
#              {'id': 'rec5SLix4yQxuzXgE',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Ninjask',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 50,
#                          '#': 291,
#                          'Generation': 3,
#                          'Attack': 90,
#                          'Defense': 45,
#                          'Total': 456,
#                          'Sp. Def': 50,
#                          'HP': 61,
#                          'Speed': 160}},
#              {'id': 'rec5bQ4AEtYWEqU7p',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'Mesprit',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 105,
#                          '#': 481,
#                          'Generation': 4,
#                          'Attack': 105,
#                          'Defense': 105,
#                          'Total': 580,
#                          'Sp. Def': 105,
#                          'HP': 80,
#                          'Speed': 80}},
#              {'id': 'rec5gbcQ9lNAW7qkX',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'ThundurusTherian Forme',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Electric',
#                          'Sp. Atk': 145,
#                          '#': 642,
#                          'Generation': 5,
#                          'Attack': 105,
#                          'Defense': 70,
#                          'Total': 580,
#                          'Sp. Def': 80,
#                          'HP': 79,
#                          'Speed': 101}},
#              {'id': 'rec5gdLlAnpRtnzEN',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Binacle',
#                          'Type 2': 'Water',
#                          'Type 1': 'Rock',
#                          'Sp. Atk': 39,
#                          '#': 688,
#                          'Generation': 6,
#                          'Attack': 52,
#                          'Defense': 67,
#                          'Total': 306,
#                          'Sp. Def': 56,
#                          'HP': 42,
#                          'Speed': 50}},
#              {'id': 'rec5l5beC7va0vQKK',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Exploud',
#                          'Type 1': 'Normal',
#                          'Sp. Atk': 91,
#                          '#': 295,
#                          'Generation': 3,
#                          'Attack': 91,
#                          'Defense': 63,
#                          'Total': 490,
#                          'Sp. Def': 73,
#                          'HP': 104,
#                          'Speed': 68}},
#              {'id': 'rec5mcqNrBkvdTyb5',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Foongus',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Grass',
#                          'Sp. Atk': 55,
#                          '#': 590,
#                          'Generation': 5,
#                          'Attack': 55,
#                          'Defense': 45,
#                          'Total': 294,
#                          'Sp. Def': 55,
#                          'HP': 69,
#                          'Speed': 15}},
#              {'id': 'rec5p8rXtpVcSMtcw',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Sandshrew',
#                          'Type 1': 'Ground',
#                          'Sp. Atk': 20,
#                          '#': 27,
#                          'Generation': 1,
#                          'Attack': 75,
#                          'Defense': 85,
#                          'Total': 300,
#                          'Sp. Def': 30,
#                          'HP': 50,
#                          'Speed': 40}},
#              {'id': 'rec60lVHA5b6kXIJq',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Omanyte',
#                          'Type 2': 'Water',
#                          'Type 1': 'Rock',
#                          'Sp. Atk': 90,
#                          '#': 138,
#                          'Generation': 1,
#                          'Attack': 40,
#                          'Defense': 100,
#                          'Total': 355,
#                          'Sp. Def': 55,
#                          'HP': 35,
#                          'Speed': 35}},
#              {'id': 'rec6801gcOjuaIVcN',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'Victini',
#                          'Type 2': 'Fire',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 100,
#                          '#': 494,
#                          'Generation': 5,
#                          'Attack': 100,
#                          'Defense': 100,
#                          'Total': 600,
#                          'Sp. Def': 100,
#                          'HP': 100,
#                          'Speed': 100}},
#              {'id': 'rec6FnC3L3VfTBZdS',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Infernape',
#                          'Type 2': 'Fighting',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 104,
#                          '#': 392,
#                          'Generation': 4,
#                          'Attack': 104,
#                          'Defense': 71,
#                          'Total': 534,
#                          'Sp. Def': 71,
#                          'HP': 76,
#                          'Speed': 108}},
#              {'id': 'rec6KE8gTPCqoqeoJ',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Duskull',
#                          'Type 1': 'Ghost',
#                          'Sp. Atk': 30,
#                          '#': 355,
#                          'Generation': 3,
#                          'Attack': 40,
#                          'Defense': 90,
#                          'Total': 295,
#                          'Sp. Def': 90,
#                          'HP': 20,
#                          'Speed': 25}},
#              {'id': 'rec6KXCJBdsIYrpMf',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Burmy',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 29,
#                          '#': 412,
#                          'Generation': 4,
#                          'Attack': 29,
#                          'Defense': 45,
#                          'Total': 224,
#                          'Sp. Def': 45,
#                          'HP': 40,
#                          'Speed': 36}},
#              {'id': 'rec6e5ZjROi0b5Oy9',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Feebas',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 10,
#                          '#': 349,
#                          'Generation': 3,
#                          'Attack': 15,
#                          'Defense': 20,
#                          'Total': 200,
#                          'Sp. Def': 55,
#                          'HP': 20,
#                          'Speed': 80}},
#              {'id': 'rec6t5jKMAH1rCDcD',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Skorupi',
#                          'Type 2': 'Bug',
#                          'Type 1': 'Poison',
#                          'Sp. Atk': 30,
#                          '#': 451,
#                          'Generation': 4,
#                          'Attack': 50,
#                          'Defense': 90,
#                          'Total': 330,
#                          'Sp. Def': 55,
#                          'HP': 40,
#                          'Speed': 65}},
#              {'id': 'rec6ymW25h1w6FHnQ',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Shelmet',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 40,
#                          '#': 616,
#                          'Generation': 5,
#                          'Attack': 40,
#                          'Defense': 85,
#                          'Total': 305,
#                          'Sp. Def': 65,
#                          'HP': 50,
#                          'Speed': 25}},
#              {'id': 'rec70nwnKW051RMU5',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Shellos',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 57,
#                          '#': 422,
#                          'Generation': 4,
#                          'Attack': 48,
#                          'Defense': 48,
#                          'Total': 325,
#                          'Sp. Def': 62,
#                          'HP': 76,
#                          'Speed': 34}},
#              {'id': 'rec7HEtF5eTTbXxow',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Mienfoo',
#                          'Type 1': 'Fighting',
#                          'Sp. Atk': 55,
#                          '#': 619,
#                          'Generation': 5,
#                          'Attack': 85,
#                          'Defense': 50,
#                          'Total': 350,
#                          'Sp. Def': 50,
#                          'HP': 45,
#                          'Speed': 65}},
#              {'id': 'rec7L1Nqz87hrFcPE',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'DiancieMega Diancie',
#                          'Type 2': 'Fairy',
#                          'Type 1': 'Rock',
#                          'Sp. Atk': 160,
#                          '#': 719,
#                          'Generation': 6,
#                          'Attack': 160,
#                          'Defense': 110,
#                          'Total': 700,
#                          'Sp. Def': 110,
#                          'HP': 50,
#                          'Speed': 110}},
#              {'id': 'rec7LX8mNOqkXfEr9',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Gible',
#                          'Type 2': 'Ground',
#                          'Type 1': 'Dragon',
#                          'Sp. Atk': 40,
#                          '#': 443,
#                          'Generation': 4,
#                          'Attack': 70,
#                          'Defense': 45,
#                          'Total': 300,
#                          'Sp. Def': 45,
#                          'HP': 58,
#                          'Speed': 42}},
#              {'id': 'rec7NVV7A6fExQdGp',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Poliwhirl',
#                          'Type 1': 'Water',
#                          'Sp. Atk': 50,
#                          '#': 61,
#                          'Generation': 1,
#                          'Attack': 65,
#                          'Defense': 65,
#                          'Total': 385,
#                          'Sp. Def': 50,
#                          'HP': 65,
#                          'Speed': 90}},
#              {'id': 'rec7Npx6k7tEOMsLX',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Krokorok',
#                          'Type 2': 'Dark',
#                          'Type 1': 'Ground',
#                          'Sp. Atk': 45,
#                          '#': 552,
#                          'Generation': 5,
#                          'Attack': 82,
#                          'Defense': 45,
#                          'Total': 351,
#                          'Sp. Def': 45,
#                          'HP': 60,
#                          'Speed': 74}},
#              {'id': 'rec7Q0lkXh6j2zi3i',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Combee',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 30,
#                          '#': 415,
#                          'Generation': 4,
#                          'Attack': 30,
#                          'Defense': 42,
#                          'Total': 244,
#                          'Sp. Def': 42,
#                          'HP': 30,
#                          'Speed': 70}},
#              {'id': 'rec7WlcBMw04Xdmfn',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Ariados',
#                          'Type 2': 'Poison',
#                          'Type 1': 'Bug',
#                          'Sp. Atk': 60,
#                          '#': 168,
#                          'Generation': 2,
#                          'Attack': 90,
#                          'Defense': 70,
#                          'Total': 390,
#                          'Sp. Def': 60,
#                          'HP': 70,
#                          'Speed': 40}},
#              {'id': 'rec7cKpCGollDer79',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Simisear',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 98,
#                          '#': 514,
#                          'Generation': 5,
#                          'Attack': 98,
#                          'Defense': 63,
#                          'Total': 498,
#                          'Sp. Def': 63,
#                          'HP': 75,
#                          'Speed': 101}},
#              {'id': 'rec7eFXwIophCWJ8l',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Weavile',
#                          'Type 2': 'Ice',
#                          'Type 1': 'Dark',
#                          'Sp. Atk': 45,
#                          '#': 461,
#                          'Generation': 4,
#                          'Attack': 120,
#                          'Defense': 65,
#                          'Total': 510,
#                          'Sp. Def': 85,
#                          'HP': 70,
#                          'Speed': 125}},
#              {'id': 'rec7ia361aHbRuevv',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Misdreavus',
#                          'Type 1': 'Ghost',
#                          'Sp. Atk': 85,
#                          '#': 200,
#                          'Generation': 2,
#                          'Attack': 60,
#                          'Defense': 60,
#                          'Total': 435,
#                          'Sp. Def': 85,
#                          'HP': 60,
#                          'Speed': 85}},
#              {'id': 'rec7qo7yo6Gwvd56c',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Sylveon',
#                          'Type 1': 'Fairy',
#                          'Sp. Atk': 110,
#                          '#': 700,
#                          'Generation': 6,
#                          'Attack': 65,
#                          'Defense': 65,
#                          'Total': 525,
#                          'Sp. Def': 130,
#                          'HP': 95,
#                          'Speed': 60}},
#              {'id': 'rec7uT0aMdPAlgRdf',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Name': 'Numel',
#                          'Type 2': 'Ground',
#                          'Type 1': 'Fire',
#                          'Sp. Atk': 65,
#                          '#': 322,
#                          'Generation': 3,
#                          'Attack': 60,
#                          'Defense': 40,
#                          'Total': 305,
#                          'Sp. Def': 45,
#                          'HP': 60,
#                          'Speed': 35}},
#              {'id': 'rec7zGpoEZPVvzLXe',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'DeoxysAttack Forme',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 180,
#                          '#': 386,
#                          'Generation': 3,
#                          'Attack': 180,
#                          'Defense': 20,
#                          'Total': 600,
#                          'Sp. Def': 20,
#                          'HP': 50,
#                          'Speed': 150}},
#              {'id': 'rec7zxtWAmg5Yni1Y',
#               'createdTime': '2023-10-24T18:18:50.000Z',
#               'fields': {'Legendary': True,
#                          'Name': 'Lugia',
#                          'Type 2': 'Flying',
#                          'Type 1': 'Psychic',
#                          'Sp. Atk': 90,
#                          '#': 249,
#                          'Generation': 2,
#                          'Attack': 90,
#                          'Defense': 130,
#                          'Total': 680,
#                          'Sp. Def': 154,
#                          'HP': 106,
#                          'Speed': 110}}],
#  'offset': 'itrd0HzSxBvmVL0RX/rec7zxtWAmg5Yni1Y'}
# ------------------------------------------------------------------------------------------------------------------------

# %%
print(records_id)
# Out:
# ['rec024U5m04leThgR', 'rec02nAj8FEGimqIo', 'rec0FaekQXOmqm43r', 'rec0K6M4Pb8fiA7mv', 'rec0KQmVKYKrAutqz', 'rec0YbfJ3d2dejn92', 'rec0cMIc3lHMJdOK5', 'rec0dOOELRdXXTlWY', 'rec0hznr3w1jk2vMh', 'rec0kU4DCB35N9HD2', 'rec0oVF8wrQkT3tHy', 'rec0rMrberGHuLwVV', 'rec0w02diRXOqVrPY', 'rec12SgksrLd36rqY', 'rec12abgTdHHSlWn7', 'rec16LhpOs4sDO3nb', 'rec17USZ2YCFT8Dc5', 'rec19CW8nfBsFNfga', 'rec1DIUqtbSfQ0b2l', 'rec1IEc9tKckPURVY', 'rec1LhHk3SITAJfXK', 'rec1WLUsOksHMa0u7', 'rec1XBapUx5DCWQdd', 'rec1g1yYOoi3RBTzW', 'rec1hQPhSreJnSrjk', 'rec1hTaEZpTi8l0bF', 'rec1hhLJG2uvzRXi6', 'rec1wZyUrcobM2veI', 'rec25g7Tvgl83FxUG', 'rec2DhrTIsNufQNRH', 'rec2HhQIdKoHrCniB', 'rec2KdJu1BD7rqcKk', 'rec2o905ev7IhoHuB', 'rec2serVzfrxMnX3M', 'rec2tLnVoh2Ndcpxx', 'rec2yDdaOur9YBcXe', 'rec37FUE7ylmYlVQG', 'rec3IQr50WYQCZ9p3', 'rec3ITZAJXGHOytWd', 'rec3Os6BXdyHEdw2p', 'rec3P8Q6WD7m6GJHa', 'rec3Xl4K7Y0s044Py', 'rec3apInrfEEeCYcE', 'rec3coqMrgybHU9x4', 'rec3iiHRYFmFfLIfi', 'rec3l0aE34fKNDGik', 'rec3nx2qTl4F6O42d', 'rec3wF44V77lI8IlN', 'rec3xhlzuGQVeOJDV', 'rec3yk0e181ZWbykA', 'rec3yw77dvOd8LMvx', 'rec41sQ9iCz5Owp3v', 'rec43uI5sfTPHLDa7', 'rec487e50KubCWDyf', 'rec4BlzLUcBMxOzGw', 'rec4FMmx8yQWvCU3j', 'rec4WY0eHFuaHQT4f', 'rec4ZK9fHhjgp8h6v', 'rec4gtWPLotRKNgLY', 'rec4gx3LXGyR6yjEr', 'rec4hdqjWxolM05Jm', 'rec4i0grKLZaCbTDO', 'rec4j5Bb8WfXpyWzo', 'rec4pHxhpAYNiaAob', 'rec4qqLldKUI3kWPb', 'rec51D1EAJq4W5KSl', 'rec59wZCRN3S2ojYM', 'rec5AaGKmN0H86kpI', 'rec5Ajv0vtv1w1Sw6', 'rec5QIM8DPz7KCNoO', 'rec5SLix4yQxuzXgE', 'rec5bQ4AEtYWEqU7p', 'rec5gbcQ9lNAW7qkX', 'rec5gdLlAnpRtnzEN', 'rec5l5beC7va0vQKK', 'rec5mcqNrBkvdTyb5', 'rec5p8rXtpVcSMtcw', 'rec60lVHA5b6kXIJq', 'rec6801gcOjuaIVcN', 'rec6FnC3L3VfTBZdS', 'rec6KE8gTPCqoqeoJ', 'rec6KXCJBdsIYrpMf', 'rec6e5ZjROi0b5Oy9', 'rec6t5jKMAH1rCDcD', 'rec6ymW25h1w6FHnQ', 'rec70nwnKW051RMU5', 'rec7HEtF5eTTbXxow', 'rec7L1Nqz87hrFcPE', 'rec7LX8mNOqkXfEr9', 'rec7NVV7A6fExQdGp', 'rec7Npx6k7tEOMsLX', 'rec7Q0lkXh6j2zi3i', 'rec7WlcBMw04Xdmfn', 'rec7cKpCGollDer79', 'rec7eFXwIophCWJ8l', 'rec7ia361aHbRuevv', 'rec7qo7yo6Gwvd56c', 'rec7uT0aMdPAlgRdf', 'rec7zGpoEZPVvzLXe', 'rec7zxtWAmg5Yni1Y']

# %% [markdown]
# **Notas de la documentación**:
#
# ```html
# Pagination
# The server returns one page of records at a time. Each page will contain pageSize records, which is 100 by default.
#
# If there are more records, the response will contain an offset. To fetch the next page of records, include offset in the next request's parameters.
#
# Pagination will stop when you've reached the end of your table. If the maxRecords parameter is passed, pagination will stop once you've reached this maximum.
# ```
#
# Si quisieramos extraer más de 100 elementos, debemos usar el parámetro **offset** en el endpoint **GET**. La primera llamada no tendrá el parámetro **offset** pero retornará en el **JSON**  el **offset** que debemos agregar en la siguiente llamada como paràmetro.

# %%
# %%time

params = {}

endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}"

datos = list()

while params.get("offset") != None or len(datos) == 0:
    
    response = requests.get(url = endpoint, headers = headers, params = params)
    
    print(f"response: {response.status_code}")
    print(f"endpoint: {response.url}")
    
    data = response.json()
    
    offset = data.get("offset")
    
    params["offset"] = offset
    
    datos.extend(data["records"])
    
print(len(datos))
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2Frec7zxtWAmg5Yni1Y
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2FrecFEvgoHhfAPKhys
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2FrecOSPySkIkbCgmDz
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2FrecVCyhrpeGFjcIVs
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2Frecd7qDHjgDuwQlyX
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2FrecjyMKdrDrw7lbSr
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?offset=itrxWT1ahaPSrNotB%2FrecsMfWAjfO2dzj0t
# 800
# CPU times: total: 0 ns
# Wall time: 5.1 s

# %%
pprint(datos[0]["fields"])
# Out:
# {'#': 427,
#  'Attack': 66,
#  'Defense': 44,
#  'Generation': 4,
#  'HP': 55,
#  'Name': 'Buneary',
#  'Sp. Atk': 44,
#  'Sp. Def': 56,
#  'Speed': 85,
#  'Total': 350,
#  'Type 1': 'Normal'}

# %% [markdown]
# ### 02. Retrieve a Record
#
# ```html
# endpoint: https://api.airtable.com/v0/{BASE_ID}/{TABLE_ID}/{RECORD_ID}
# HTTP method: GET
# ```

# %%
# Retrieve a Record

# Endpoint

RECORD_ID = records_id[0]
endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}/{RECORD_ID}"

print(endpoint)
# Out:
# https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon/rec024U5m04leThgR

# %%
response = requests.get(url = endpoint, headers = headers)

print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = False)

print("-"*120)
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon/rec024U5m04leThgR
# ------------------------------------------------------------------------------------------------------------------------
# {'id': 'rec024U5m04leThgR',
#  'createdTime': '2023-10-24T18:18:50.000Z',
#  'fields': {'Name': 'Buneary',
#             'Type 1': 'Normal',
#             'Sp. Atk': 44,
#             '#': 427,
#             'Generation': 4,
#             'Attack': 66,
#             'Defense': 44,
#             'Total': 350,
#             'Sp. Def': 56,
#             'HP': 55,
#             'Speed': 85}}
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 03. Create Records
#
# ```html
# endpoint: https://api.airtable.com/v0/{BASE_ID}/{TABLE_ID}
# HTTP method: POST
# ```
#
# **Notas de la documentación**:
# ```html
# Your request body should include an array of up to 10 record objects. Each of these objects should have one key whose value is an inner object containing your record's cell values, keyed by either field name or field id.
#
# Returns an array of record objects created if the call succeeded, including record IDs which will uniquely identify the records within Tabla API.
# ```
#
# **Estructura de los datos**:
# ```python
# {"records" : [{"fields" : {}},
#               {"fields" : {}}]}
# ```

# %%
BASE_ID = "appwVbYoCYZjw2K8u"
TABLE_ID = "tblkjGQCfG4dUSCon"

# %%
# Create Records

# Endpoint
endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}"

print(endpoint)
# Out:
# https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon

# %%
df = pd.read_csv("../Actividades/csv/Pokemon.csv")

df = df.sample(15).dropna()[:10]

df
# Out:
#        #       Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 271  251     Celebi  Psychic   Grass    600  100     100      100      100
# 456  411  Bastiodon     Rock   Steel    495   60      52      168       47
# 316  292   Shedinja      Bug   Ghost    236    1      90       45       30
# 17    14     Kakuna      Bug  Poison    205   45      25       50       25
# 461  414     Mothim      Bug  Flying    424   70      94       50       94
# 203  188   Skiploom    Grass  Flying    340   55      45       50       45
#
#      Sp. Def  Speed  Generation  Legendary
# 271      100    100           2      False
# 456      138     30           4      False
# 316       30     40           3      False
# 17        25     35           1      False
# 461       50     66           4      False
# 203       65     80           2      False

# %%
pprint(df.iloc[0, :].to_dict())
# Out:
# {'#': 251,
#  'Attack': 100,
#  'Defense': 100,
#  'Generation': 2,
#  'HP': 100,
#  'Legendary': False,
#  'Name': 'Celebi',
#  'Sp. Atk': 100,
#  'Sp. Def': 100,
#  'Speed': 100,
#  'Total': 600,
#  'Type 1': 'Psychic',
#  'Type 2': 'Grass'}

# %%
# Bucle normal

records = {"records" : []}

for i in range(df.shape[0]):
    
    fila = {"fields" : df.iloc[i, :].to_dict()}
    
    records["records"].append(fila)
    
# records

# %%
records
# Out:
# {'records': [{'fields': {'#': 251,
#     'Name': 'Celebi',
#     'Type 1': 'Psychic',
#     'Type 2': 'Grass',
#     'Total': 600,
#     'HP': 100,
#     'Attack': 100,
#     'Defense': 100,
#     'Sp. Atk': 100,
#     'Sp. Def': 100,
#     'Speed': 100,
#     'Generation': 2,
#     'Legendary': False}},
#   {'fields': {'#': 411,
#     'Name': 'Bastiodon',
#     'Type 1': 'Rock',
#     'Type 2': 'Steel',
#     'Total': 495,
#     'HP': 60,
#     'Attack': 52,
#     'Defense': 168,
#     'Sp. Atk': 47,
#     'Sp. Def': 138,
#     'Speed': 30,
#     'Generation': 4,
#     'Legendary': False}},
#   {'fields': {'#': 292,
#     'Name': 'Shedinja',
#     'Type 1': 'Bug',
#     'Type 2': 'Ghost',
#     'Total': 236,
#     'HP': 1,
#     'Attack': 90,
#     'Defense': 45,
#     'Sp. Atk': 30,
#     'Sp. Def': 30,
#     'Speed': 40,
#     'Generation': 3,
#     'Legendary': False}},
#   {'fields': {'#': 14,
#     'Name': 'Kakuna',
#     'Type 1': 'Bug',
#     'Type 2': 'Poison',
#     'Total': 205,
#     'HP': 45,
#     'Attack': 25,
#     'Defense': 50,
#     'Sp. Atk': 25,
#     'Sp. Def': 25,
#     'Speed': 35,
#     'Generation': 1,
#     'Legendary': False}},
#   {'fields': {'#': 414,
#     'Name': 'Mothim',
#     'Type 1': 'Bug',
#     'Type 2': 'Flying',
#     'Total': 424,
#     'HP': 70,
#     'Attack': 94,
#     'Defense': 50,
#     'Sp. Atk': 94,
#     'Sp. Def': 50,
#     'Speed': 66,
#     'Generation': 4,
#     'Legendary': False}},
#   {'fields': {'#': 188,
#     'Name': 'Skiploom',
#     'Type 1': 'Grass',
#     'Type 2': 'Flying',
#     'Total': 340,
#     'HP': 55,
#     'Attack': 45,
#     'Defense': 50,
#     'Sp. Atk': 45,
#     'Sp. Def': 65,
#     'Speed': 80,
#     'Generation': 2,
#     'Legendary': False}}]}

# %%
pprint({"records" : [{"fields" : df.iloc[i, :].to_dict()} for i in range(df.shape[0])]})

datos_subir = {"records" : [{"fields" : df.iloc[i, :].to_dict()} for i in range(df.shape[0])]}
# Out:
# {'records': [{'fields': {'#': 251,
#                          'Attack': 100,
#                          'Defense': 100,
#                          'Generation': 2,
#                          'HP': 100,
#                          'Legendary': False,
#                          'Name': 'Celebi',
#                          'Sp. Atk': 100,
#                          'Sp. Def': 100,
#                          'Speed': 100,
#                          'Total': 600,
#                          'Type 1': 'Psychic',
#                          'Type 2': 'Grass'}},
#              {'fields': {'#': 411,
#                          'Attack': 52,
#                          'Defense': 168,
#                          'Generation': 4,
#                          'HP': 60,
#                          'Legendary': False,
#                          'Name': 'Bastiodon',
#                          'Sp. Atk': 47,
#                          'Sp. Def': 138,
#                          'Speed': 30,
#                          'Total': 495,
#                          'Type 1': 'Rock',
#                          'Type 2': 'Steel'}},
#              {'fields': {'#': 292,
#                          'Attack': 90,
#                          'Defense': 45,
#                          'Generation': 3,
#                          'HP': 1,
#                          'Legendary': False,
#                          'Name': 'Shedinja',
#                          'Sp. Atk': 30,
#                          'Sp. Def': 30,
#                          'Speed': 40,
#                          'Total': 236,
#                          'Type 1': 'Bug',
#                          'Type 2': 'Ghost'}},
#              {'fields': {'#': 14,
#                          'Attack': 25,
#                          'Defense': 50,
#                          'Generation': 1,
#                          'HP': 45,
#                          'Legendary': False,
#                          'Name': 'Kakuna',
#                          'Sp. Atk': 25,
#                          'Sp. Def': 25,
#                          'Speed': 35,
#                          'Total': 205,
#                          'Type 1': 'Bug',
#                          'Type 2': 'Poison'}},
#              {'fields': {'#': 414,
#                          'Attack': 94,
#                          'Defense': 50,
#                          'Generation': 4,
#                          'HP': 70,
#                          'Legendary': False,
#                          'Name': 'Mothim',
#                          'Sp. Atk': 94,
#                          'Sp. Def': 50,
#                          'Speed': 66,
#                          'Total': 424,
#                          'Type 1': 'Bug',
#                          'Type 2': 'Flying'}},
#              {'fields': {'#': 188,
#                          'Attack': 45,
#                          'Defense': 50,
#                          'Generation': 2,
#                          'HP': 55,
#                          'Legendary': False,
#                          'Name': 'Skiploom',
#                          'Sp. Atk': 45,
#                          'Sp. Def': 65,
#                          'Speed': 80,
#                          'Total': 340,
#                          'Type 1': 'Grass',
#                          'Type 2': 'Flying'}}]}

# %%
response = requests.post(url = endpoint, json = datos_subir, headers = headers)

print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = False)

print("-"*120)
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon
# ------------------------------------------------------------------------------------------------------------------------
# {'records': [{'id': 'rec17xiaovt17Nyd4',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 251,
#                          'Name': 'Celebi',
#                          'Type 1': 'Psychic',
#                          'Type 2': 'Grass',
#                          'Total': 600,
#                          'HP': 100,
#                          'Attack': 100,
#                          'Defense': 100,
#                          'Sp. Atk': 100,
#                          'Sp. Def': 100,
#                          'Speed': 100,
#                          'Generation': 2}},
#              {'id': 'reckDgldQDSkfwIX5',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 411,
#                          'Name': 'Bastiodon',
#                          'Type 1': 'Rock',
#                          'Type 2': 'Steel',
#                          'Total': 495,
#                          'HP': 60,
#                          'Attack': 52,
#                          'Defense': 168,
#                          'Sp. Atk': 47,
#                          'Sp. Def': 138,
#                          'Speed': 30,
#                          'Generation': 4}},
#              {'id': 'recgIojU7Ph3hgshF',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 292,
#                          'Name': 'Shedinja',
#                          'Type 1': 'Bug',
#                          'Type 2': 'Ghost',
#                          'Total': 236,
#                          'HP': 1,
#                          'Attack': 90,
#                          'Defense': 45,
#                          'Sp. Atk': 30,
#                          'Sp. Def': 30,
#                          'Speed': 40,
#                          'Generation': 3}},
#              {'id': 'recEMTes78PnPDaiR',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 14,
#                          'Name': 'Kakuna',
#                          'Type 1': 'Bug',
#                          'Type 2': 'Poison',
#                          'Total': 205,
#                          'HP': 45,
#                          'Attack': 25,
#                          'Defense': 50,
#                          'Sp. Atk': 25,
#                          'Sp. Def': 25,
#                          'Speed': 35,
#                          'Generation': 1}},
#              {'id': 'rec3KrZ8cSN0EFANN',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 414,
#                          'Name': 'Mothim',
#                          'Type 1': 'Bug',
#                          'Type 2': 'Flying',
#                          'Total': 424,
#                          'HP': 70,
#                          'Attack': 94,
#                          'Defense': 50,
#                          'Sp. Atk': 94,
#                          'Sp. Def': 50,
#                          'Speed': 66,
#                          'Generation': 4}},
#              {'id': 'recODZFzmCM39j4FZ',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 188,
#                          'Name': 'Skiploom',
#                          'Type 1': 'Grass',
#                          'Type 2': 'Flying',
#                          'Total': 340,
#                          'HP': 55,
#                          'Attack': 45,
#                          'Defense': 50,
#                          'Sp. Atk': 45,
#                          'Sp. Def': 65,
#                          'Speed': 80,
#                          'Generation': 2}}]}
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 04. Update Records
#
# ```html
# endpoint: https://api.airtable.com/v0/{BASE_ID}/{TABLE_ID}
# HTTP method: PATCH
# ```
#
# **Notas de la documentación**:
# ```html
# Your request body should include an array of up to 10 record objects. Each of these objects should have an id property representing the record ID and a fields property which contains all of your record's cell values by field name or field id for all of your record's cell values by field name.
# ```
#
# **Estructura de los datos**:
# ```python
# {"records" : [{"id"     : "",
#                "fields" : {"field_1" : ""
#                            "field_2" : ""}}]}
# ```

# %%
# Update Records

# Endpoint
endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}"

print(endpoint)
# Out:
# https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon

# %%
records_id = response.json()['records']

# %%
records_id[1]
# Out:
# {'id': 'reckDgldQDSkfwIX5',
#  'createdTime': '2023-10-25T15:45:23.000Z',
#  'fields': {'#': 411,
#   'Name': 'Bastiodon',
#   'Type 1': 'Rock',
#   'Type 2': 'Steel',
#   'Total': 495,
#   'HP': 60,
#   'Attack': 52,
#   'Defense': 168,
#   'Sp. Atk': 47,
#   'Sp. Def': 138,
#   'Speed': 30,
#   'Generation': 4}}

# %%
datos_modificar = {"records" : [{"id" : x['id'], "fields" : x['fields']} for x in records_id[-2:]]}
datos_modificar
# Out:
# {'records': [{'id': 'rec3KrZ8cSN0EFANN',
#    'fields': {'#': 414,
#     'Name': 'Mothim',
#     'Type 1': 'Bug',
#     'Type 2': 'Flying',
#     'Total': 424,
#     'HP': 70,
#     'Attack': 94,
#     'Defense': 50,
#     'Sp. Atk': 94,
#     'Sp. Def': 50,
#     'Speed': 66,
#     'Generation': 4}},
#   {'id': 'recODZFzmCM39j4FZ',
#    'fields': {'#': 188,
#     'Name': 'Skiploom',
#     'Type 1': 'Grass',
#     'Type 2': 'Flying',
#     'Total': 340,
#     'HP': 55,
#     'Attack': 45,
#     'Defense': 50,
#     'Sp. Atk': 45,
#     'Sp. Def': 65,
#     'Speed': 80,
#     'Generation': 2}}]}

# %%
for i in range(len(datos_modificar["records"])):
    
    for col in ["Name"]:
        
        datos_modificar["records"][i]["fields"][col] = "Receta de mi coño en vinagre"
    
pprint(datos_modificar)
# Out:
# {'records': [{'fields': {'#': 414,
#                          'Attack': 94,
#                          'Defense': 50,
#                          'Generation': 4,
#                          'HP': 70,
#                          'Name': 'Receta de mi coño en vinagre',
#                          'Sp. Atk': 94,
#                          'Sp. Def': 50,
#                          'Speed': 66,
#                          'Total': 424,
#                          'Type 1': 'Bug',
#                          'Type 2': 'Flying'},
#               'id': 'rec3KrZ8cSN0EFANN'},
#              {'fields': {'#': 188,
#                          'Attack': 45,
#                          'Defense': 50,
#                          'Generation': 2,
#                          'HP': 55,
#                          'Name': 'Receta de mi coño en vinagre',
#                          'Sp. Atk': 45,
#                          'Sp. Def': 65,
#                          'Speed': 80,
#                          'Total': 340,
#                          'Type 1': 'Grass',
#                          'Type 2': 'Flying'},
#               'id': 'recODZFzmCM39j4FZ'}]}

# %%
response = requests.patch(url = endpoint, json = datos_modificar, headers = headers)

print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = False)

print("-"*120)
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon
# ------------------------------------------------------------------------------------------------------------------------
# {'records': [{'id': 'rec3KrZ8cSN0EFANN',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 414,
#                          'Name': 'Receta de mi coño en vinagre',
#                          'Type 1': 'Bug',
#                          'Type 2': 'Flying',
#                          'Total': 424,
#                          'HP': 70,
#                          'Attack': 94,
#                          'Defense': 50,
#                          'Sp. Atk': 94,
#                          'Sp. Def': 50,
#                          'Speed': 66,
#                          'Generation': 4}},
#              {'id': 'recODZFzmCM39j4FZ',
#               'createdTime': '2023-10-25T15:45:23.000Z',
#               'fields': {'#': 188,
#                          'Name': 'Receta de mi coño en vinagre',
#                          'Type 1': 'Grass',
#                          'Type 2': 'Flying',
#                          'Total': 340,
#                          'HP': 55,
#                          'Attack': 45,
#                          'Defense': 50,
#                          'Sp. Atk': 45,
#                          'Sp. Def': 65,
#                          'Speed': 80,
#                          'Generation': 2}}]}
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 05. Delete Records
#
# ```html
# endpoint: https://api.airtable.com/v0/{BASE_ID}/{TABLE_ID}
# HTTP method: DELETE
# ```
#
# **Notas de la documentación**:
# ```html
# Your request should include a URL-encoded array of up to 10 record IDs to delete.
# ```
#
# **Estructura de los datos**:
# ```python
# 'records[]=id&records[]=id&records[]=id&records[]=id&records[]=id&records[]=id&records[]=id&records[]=id&records[]=id&records[]=id'
# ```

# %%
# Delete Records

# Endpoint
endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}"

print(endpoint)
# Out:
# https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon

# %%
# url-encoded

params = "&".join([f"records[]={x['id']}" for x in records_id[:10]])
params
# Out:
# 'records[]=rec17xiaovt17Nyd4&records[]=reckDgldQDSkfwIX5&records[]=recgIojU7Ph3hgshF&records[]=recEMTes78PnPDaiR&records[]=rec3KrZ8cSN0EFANN&records[]=recODZFzmCM39j4FZ'

# %%
response = requests.delete(url = endpoint, params = params, headers = headers)

print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = False)

print("-"*120)
# Out:
# response: 200
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon?records[]=rec17xiaovt17Nyd4&records[]=reckDgldQDSkfwIX5&records[]=recgIojU7Ph3hgshF&records[]=recEMTes78PnPDaiR&records[]=rec3KrZ8cSN0EFANN&records[]=recODZFzmCM39j4FZ
# ------------------------------------------------------------------------------------------------------------------------
# {'records': [{'deleted': True, 'id': 'rec17xiaovt17Nyd4'},
#              {'deleted': True, 'id': 'reckDgldQDSkfwIX5'},
#              {'deleted': True, 'id': 'recgIojU7Ph3hgshF'},
#              {'deleted': True, 'id': 'recEMTes78PnPDaiR'},
#              {'deleted': True, 'id': 'rec3KrZ8cSN0EFANN'},
#              {'deleted': True, 'id': 'recODZFzmCM39j4FZ'}]}
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 06. Delete a Record
#
# ```html
# endpoint: https://api.airtable.com/v0/{BASE_ID}/{TABLE_ID}/{RECORD_ID}
# HTTP method: DELETE
# ```

# %%
records_id[1]['id']
# Out:
# 'reckDgldQDSkfwIX5'

# %%
# Delete a Record

# Endpoint

RECORD_ID = records_id[1]['id']
endpoint = f"{airtable_base_url}/{BASE_ID}/{TABLE_ID}/{RECORD_ID}"

print(endpoint)
# Out:
# https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon/reckDgldQDSkfwIX5

# %%
response = requests.delete(url = endpoint, headers = headers)

print(f"response: {response.status_code}")

print(f"endpoint: {response.url}")

print("-"*120)

pprint(response.json(), sort_dicts = False)

print("-"*120)
# Out:
# response: 403
# endpoint: https://api.airtable.com/v0/appwVbYoCYZjw2K8u/tblkjGQCfG4dUSCon/reckDgldQDSkfwIX5
# ------------------------------------------------------------------------------------------------------------------------
# {'error': {'type': 'INVALID_PERMISSIONS_OR_MODEL_NOT_FOUND',
#            'message': 'Invalid permissions, or the requested model was not '
#                       'found. Check that both your user and your token have '
#                       'the required permissions, and that the model names '
#                       'and/or ids are correct.'}}
# ------------------------------------------------------------------------------------------------------------------------

# %%
################################################################################################################################
