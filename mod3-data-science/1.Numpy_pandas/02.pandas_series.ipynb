# %% [markdown]
# ## pandas
#
# **`pandas`** es una de las librerías más utilizadas para el análisis de datos en Python.
#
# Proporciona una estructura que permite trabajar los datos y aplicar procesamiento a grandes bases de datos de forma eficiente.
#
# Consta principalmente de dos estructuras:
# - **`Series`**: Arreglos de una dimensión.
#
#
# - **`DataFrame`**: Estructura de datos de dos dimensiones similar a una tabla de Excel o una base de datos relacional en SQL. Está conformada por **`Series`**.
#
# ```python
# import pandas as pd
# ```
#
# ### Series
#
# Las **`Series`** son un tipo de dato similar a un arreglo de una dimensión de **`NumPy`** o a una lista.
#
# Para inicializar una **`Serie`** necesitamos un objeto iterable.
#
# ```python
# serie = pd.Series(["a", "b", "c", "d"])
# ```

# %%
import pandas as pd

# %%
# pd.Series() vacia

pd.Series([], dtype = "float64")
# Out:
# Series([], dtype: float64)

# %%
serie = pd.Series(["a", "b", "c", "d"], name = "letras")

serie
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: letras, dtype: object

# %%
len([i for i in dir(pd.Series()) if i.startswith("_")])
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\4230275031.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   len([i for i in dir(pd.Series()) if i.startswith("_")])
# 212

# %%
[i for i in dir(pd.Series()) if not i.startswith("_")]
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\4139426838.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   [i for i in dir(pd.Series()) if not i.startswith("_")]
# ['T',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'backfill',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'clip',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'interpolate',
#  'is_monotonic',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'iteritems',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'mad',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'std',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %% [markdown]
# ### DataFrame
#
# Un **`DataFrame`** es una estructura de datos bidimensional compuesta por **filas y columnas**, las filas se identifican con un índice y las columnas con una etiqueta o nombre de columna. Los elementos dentro del table pueden ser enteros, booleanos, cadenas, listas, tuplas...
#
# Los **`DataFrames`** pueden ser creados a partir de múltiple tipos de datos de entrada:
#
# - **`list()`**
#
#
# - **`dict()`**
#
#
# - **`.csv`**
#
#
# - **`.xlsx`**
#
#
# - **`np.arrays()`**
#
#
# - **`Tablas de SQL`**
#
#
# - **`JSON`**

# %%
# pd.DataFrame() vacio

pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Crear un pd.DataFrame() a partir de una lista

lista = list(range(100, 105))

df = pd.DataFrame()

df["nueva_columna"] = lista

df
# Out:
#    nueva_columna
# 0            100
# 1            101
# 2            102
# 3            103
# 4            104

# %%
# Crear un pd.DataFrame() a partir de una lista de listas (matriz)

lista = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

pd.DataFrame(lista)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# Se puede agregar el nombre de las columnas con el parametro "columns"

pd.DataFrame(lista, columns = ["col_1", "col_2", "col_3"])
# Out:
#    col_1  col_2  col_3
# 0      1      2      3
# 1      4      5      6
# 2      7      8      9

# %%
# Crear un pd.DataFrame() a partir de un diccionario

diccionario = {num : l for num, l in enumerate("abcdefg", start = 10)}

diccionario
# Out:
# {10: 'a', 11: 'b', 12: 'c', 13: 'd', 14: 'e', 15: 'f', 16: 'g'}

# %%
pd.DataFrame(diccionario.items())
# Out:
#     0  1
# 0  10  a
# 1  11  b
# 2  12  c
# 3  13  d
# 4  14  e
# 5  15  f
# 6  16  g

# %%
# Se puede agregar el nombre de las columnas con el parametro "columns"

pd.DataFrame(diccionario.items(), columns = ["num", "letra"])
# Out:
#    num letra
# 0   10     a
# 1   11     b
# 2   12     c
# 3   13     d
# 4   14     e
# 5   15     f
# 6   16     g

# %%
# Crear un pd.DataFrame() a partir de un .csv

pd.read_csv("Data/iris.csv")

# pandas toma la primera linea del .csv como cabecera y la usa como los nombres de las columnas
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Crear un pd.DataFrame() a partir de un .xlsx

pd.read_excel("Data/iris.xlsx")

# pandas toma la primera linea del .xlsx como cabecera y la usa como los nombres de las columnas
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 0             5.1            3.5            1.4            0.2     Iris-setosa
# 1             4.9            3.0            1.4            0.2     Iris-setosa
# 2             4.7            3.2            1.3            0.2     Iris-setosa
# 3             4.6            3.1            1.5            0.2     Iris-setosa
# 4             5.0            3.6            1.4            0.2     Iris-setosa
# ..            ...            ...            ...            ...             ...
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Vamos a guardar el DataFrame en la variable df para ver que atributos y metodos tiene.

df = pd.read_csv("Data/iris.csv")

df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# .head() nos muestra las primeras filas del DataFrame, por defecto muestra las primeras 5

df.head()
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
# 5           5.4           3.9           1.7           0.4  Iris-setosa
# 6           4.6           3.4           1.4           0.3  Iris-setosa
# 7           5.0           3.4           1.5           0.2  Iris-setosa
# 8           4.4           2.9           1.4           0.2  Iris-setosa
# 9           4.9           3.1           1.5           0.1  Iris-setosa

# %%
# .tail() nos muestra las ultimas filas del DataFrame, por defecto muestra las ultimas 5

df.tail()
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica

# %%
# Los DataFrames también tienen el método .shape

df.shape
# Out:
# (150, 5)

# %%
# Como los DataFrames tienen obligatoriamente un indice, podemos hacer que nos lo retorne

df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
# Igual con las columnas

df.columns
# Out:
# Index(['Largo Sepalo', 'Ancho Sepalo', 'Largo Petalo', 'Ancho Petalo',
#        'Clase'],
#       dtype='object')

# %%
# .describe() muestra la descripción estadística del DataFrame, retorna un pd.DataFrame()

df.describe()
# Out:
#        Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo
# count    150.000000    150.000000    150.000000    150.000000
# mean       5.843333      3.054000      3.758667      1.198667
# std        0.828066      0.433594      1.764420      0.763161
# min        4.300000      2.000000      1.000000      0.100000
# 25%        5.100000      2.800000      1.600000      0.300000
# 50%        5.800000      3.000000      4.350000      1.300000
# 75%        6.400000      3.300000      5.100000      1.800000
# max        7.900000      4.400000      6.900000      2.500000

# %%
# .info() muestra información del tipo de cada columna, memoria que utliza el dataframe, número de columnas y tamaño del índice

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Largo Sepalo  150 non-null    float64
#  1   Ancho Sepalo  150 non-null    float64
#  2   Largo Petalo  150 non-null    float64
#  3   Ancho Petalo  150 non-null    float64
#  4   Clase         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# .count() cuenta el número de elementos que no son NaN de cada columna

df.count()
# Out:
# Largo Sepalo    150
# Ancho Sepalo    150
# Largo Petalo    150
# Ancho Petalo    150
# Clase           150
# dtype: int64

# %%
# .sum() retorna la suma de cada columna de sus elementos (Solo aplica para columnas que se puedan sumar)
    
df.sum()
# Out:
# Largo Sepalo                                                876.5
# Ancho Sepalo                                                458.1
# Largo Petalo                                                563.8
# Ancho Petalo                                                179.8
# Clase           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
# .sum(axis = 1) retorna la suma horizantal de cada fila
# Por defecto axis = 0

df.sum(axis = 1)
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\3990405911.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis = 1)
# 0      10.2
# 1       9.5
# 2       9.4
# 3       9.4
# 4      10.2
#        ...
# 145    17.2
# 146    15.7
# 147    16.7
# 148    17.3
# 149    15.8
# Length: 150, dtype: float64

# %%
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# .cumsum() Suma acumulada hacia abajo

df.cumsum()
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# 0             5.1           3.5           1.4           0.2
# 1            10.0           6.5           2.8           0.4
# 2            14.7           9.7           4.1           0.6
# 3            19.3          12.8           5.6           0.8
# 4            24.3          16.4           7.0           1.0
# ..            ...           ...           ...           ...
# 145         851.6         446.2         543.1         171.8
# 146         857.9         448.7         548.1         173.7
# 147         864.4         451.7         553.3         175.7
# 148         870.6         455.1         558.7         178.0
# 149         876.5         458.1         563.8         179.8
#
#                                                  Clase
# 0                                          Iris-setosa
# 1                               Iris-setosaIris-setosa
# 2                    Iris-setosaIris-setosaIris-setosa
# 3         Iris-setosaIris-setosaIris-setosaIris-setosa
# 4    Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# ..                                                 ...
# 145  Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# 146  Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# 147  Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# 148  Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# 149  Iris-setosaIris-setosaIris-setosaIris-setosaIr...
#
# [150 rows x 5 columns]

# %%
# .min() muestra el minimo de cada columna

df.min()
# Out:
# Largo Sepalo            4.3
# Ancho Sepalo            2.0
# Largo Petalo            1.0
# Ancho Petalo            0.1
# Clase           Iris-setosa
# dtype: object

# %%
# .max() muestra el maximo de cada columna

df.max()
# Out:
# Largo Sepalo               7.9
# Ancho Sepalo               4.4
# Largo Petalo               6.9
# Ancho Petalo               2.5
# Clase           Iris-virginica
# dtype: object

# %%
# .mean() muestra la media de cada columna

df.mean()
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\2708509958.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Largo Sepalo    5.843333
# Ancho Sepalo    3.054000
# Largo Petalo    3.758667
# Ancho Petalo    1.198667
# dtype: float64

# %%
# .median() muestra la mediana de cada columna 
# La mediana es el valor que ocupa el lugar central de todos los datos cuando éstos están ordenados de menor a mayor.

df.median()
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\3569998649.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Largo Sepalo    5.80
# Ancho Sepalo    3.00
# Largo Petalo    4.35
# Ancho Petalo    1.30
# dtype: float64

# %%
# Para seleccionar una columna podemos hacer "indexing"

df["Largo Sepalo"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Largo Sepalo, Length: 150, dtype: float64

# %%
df["Clase"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Clase, Length: 150, dtype: object

# %%
# Si quiero seleccionario varias columnas debo pasar una lista de columnas

df[["Largo Sepalo", "Ancho Petalo", "Clase"]].head(3)
# Out:
#    Largo Sepalo  Ancho Petalo        Clase
# 0           5.1           0.2  Iris-setosa
# 1           4.9           0.2  Iris-setosa
# 2           4.7           0.2  Iris-setosa

# %%
# Si quiero el elemento de indice 2 de la columna "Largo Sepalo"

df["Largo Sepalo"][2]
# Out:
# 4.7

# %%
# Existe un método .iat que hace lo mismo (index at)

df["Largo Sepalo"].iat[2]
# Out:
# 4.7

# %%
# También podemos usar el método .iloc
# Con .iloc debemos darle las coordenadas, como si se tratara de una matriz

df.iloc[2][3]
# Out:
# 0.2

# %%
df.iloc[2, 3]
# Out:
# 0.2

# %%
# Si queremos usar el indice + el nombre de la columna podemos usar .at
# Este método nos deja sobreescribir valores dentro del DataFrame

df.at[0, "Largo Sepalo"] = 6.1 # cambiar el valor
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             6.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# También podemos usar .loc que nos da el mismo resultado
# Este método NO nos deja sobreescribir valores dentro del DataFrame

df.loc[0, "Largo Sepalo"]
# Out:
# 6.1

# %%
# .sort_values(column) ordena los valores del DataFrame usando como referencia una o varias columnas
# Por defecto ordena de menor a mayor
# Esta operación no es in-place

df.sort_values("Largo Sepalo")
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 13            4.3           3.0           1.1           0.1     Iris-setosa
# 38            4.4           3.0           1.3           0.2     Iris-setosa
# 8             4.4           2.9           1.4           0.2     Iris-setosa
# 42            4.4           3.2           1.3           0.2     Iris-setosa
# 41            4.5           2.3           1.3           0.3     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 117           7.7           3.8           6.7           2.2  Iris-virginica
# 118           7.7           2.6           6.9           2.3  Iris-virginica
# 122           7.7           2.8           6.7           2.0  Iris-virginica
# 135           7.7           3.0           6.1           2.3  Iris-virginica
# 131           7.9           3.8           6.4           2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Ordenando por varias columnas

df.sort_values(["Largo Sepalo", "Largo Petalo"])
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 13            4.3           3.0           1.1           0.1     Iris-setosa
# 38            4.4           3.0           1.3           0.2     Iris-setosa
# 42            4.4           3.2           1.3           0.2     Iris-setosa
# 8             4.4           2.9           1.4           0.2     Iris-setosa
# 41            4.5           2.3           1.3           0.3     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 135           7.7           3.0           6.1           2.3  Iris-virginica
# 117           7.7           3.8           6.7           2.2  Iris-virginica
# 122           7.7           2.8           6.7           2.0  Iris-virginica
# 118           7.7           2.6           6.9           2.3  Iris-virginica
# 131           7.9           3.8           6.4           2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Ordenando de mayor a menor

df.sort_values(["Largo Sepalo", "Largo Petalo"], ascending = False)
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 131           7.9           3.8           6.4           2.0  Iris-virginica
# 118           7.7           2.6           6.9           2.3  Iris-virginica
# 117           7.7           3.8           6.7           2.2  Iris-virginica
# 122           7.7           2.8           6.7           2.0  Iris-virginica
# 135           7.7           3.0           6.1           2.3  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 41            4.5           2.3           1.3           0.3     Iris-setosa
# 8             4.4           2.9           1.4           0.2     Iris-setosa
# 38            4.4           3.0           1.3           0.2     Iris-setosa
# 42            4.4           3.2           1.3           0.2     Iris-setosa
# 13            4.3           3.0           1.1           0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
# Si queremos que sea in-place podemos cambiar un parametro

df.sort_values(["Largo Sepalo", "Largo Petalo"], ascending = False, inplace = True)

# %%
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 131           7.9           3.8           6.4           2.0  Iris-virginica
# 118           7.7           2.6           6.9           2.3  Iris-virginica
# 117           7.7           3.8           6.7           2.2  Iris-virginica
# 122           7.7           2.8           6.7           2.0  Iris-virginica
# 135           7.7           3.0           6.1           2.3  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 41            4.5           2.3           1.3           0.3     Iris-setosa
# 8             4.4           2.9           1.4           0.2     Iris-setosa
# 38            4.4           3.0           1.3           0.2     Iris-setosa
# 42            4.4           3.2           1.3           0.2     Iris-setosa
# 13            4.3           3.0           1.1           0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
# .reset_index() resetea el indice
# Crea una columna nueva con el indice anterior
# Esta operación no es in-place

df.reset_index()
# Out:
#      index  Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# 0      131           7.9           3.8           6.4           2.0
# 1      118           7.7           2.6           6.9           2.3
# 2      117           7.7           3.8           6.7           2.2
# 3      122           7.7           2.8           6.7           2.0
# 4      135           7.7           3.0           6.1           2.3
# ..     ...           ...           ...           ...           ...
# 145     41           4.5           2.3           1.3           0.3
# 146      8           4.4           2.9           1.4           0.2
# 147     38           4.4           3.0           1.3           0.2
# 148     42           4.4           3.2           1.3           0.2
# 149     13           4.3           3.0           1.1           0.1
#
#               Clase
# 0    Iris-virginica
# 1    Iris-virginica
# 2    Iris-virginica
# 3    Iris-virginica
# 4    Iris-virginica
# ..              ...
# 145     Iris-setosa
# 146     Iris-setosa
# 147     Iris-setosa
# 148     Iris-setosa
# 149     Iris-setosa
#
# [150 rows x 6 columns]

# %%
# Si no queremos que se cree esa nueva columna podemos agregar al método

df.reset_index(drop = True)
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             7.9           3.8           6.4           2.0  Iris-virginica
# 1             7.7           2.6           6.9           2.3  Iris-virginica
# 2             7.7           3.8           6.7           2.2  Iris-virginica
# 3             7.7           2.8           6.7           2.0  Iris-virginica
# 4             7.7           3.0           6.1           2.3  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 145           4.5           2.3           1.3           0.3     Iris-setosa
# 146           4.4           2.9           1.4           0.2     Iris-setosa
# 147           4.4           3.0           1.3           0.2     Iris-setosa
# 148           4.4           3.2           1.3           0.2     Iris-setosa
# 149           4.3           3.0           1.1           0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
# Para hacer esta operación in-place podemos cambiar un parametro

df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             7.9           3.8           6.4           2.0  Iris-virginica
# 1             7.7           2.6           6.9           2.3  Iris-virginica
# 2             7.7           3.8           6.7           2.2  Iris-virginica
# 3             7.7           2.8           6.7           2.0  Iris-virginica
# 4             7.7           3.0           6.1           2.3  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 145           4.5           2.3           1.3           0.3     Iris-setosa
# 146           4.4           2.9           1.4           0.2     Iris-setosa
# 147           4.4           3.0           1.3           0.2     Iris-setosa
# 148           4.4           3.2           1.3           0.2     Iris-setosa
# 149           4.3           3.0           1.1           0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
# Eliminar filas o columnas
# Para esto tenemos el método .drop()
# Toma como parametro las filas/columnas que queremos eliminar
# Si quiero eliminar filas debo agregar axis = 0
# Si quiero eliminar columnas debo agregar axis = 1
# Esta operación no es in-place

df.drop(2)
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             7.9           3.8           6.4           2.0  Iris-virginica
# 1             7.7           2.6           6.9           2.3  Iris-virginica
# 3             7.7           2.8           6.7           2.0  Iris-virginica
# 4             7.7           3.0           6.1           2.3  Iris-virginica
# 5             7.6           3.0           6.6           2.1  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 145           4.5           2.3           1.3           0.3     Iris-setosa
# 146           4.4           2.9           1.4           0.2     Iris-setosa
# 147           4.4           3.0           1.3           0.2     Iris-setosa
# 148           4.4           3.2           1.3           0.2     Iris-setosa
# 149           4.3           3.0           1.1           0.1     Iris-setosa
#
# [149 rows x 5 columns]

# %%
df.drop("Clase", axis = 1)
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo
# 0             7.9           3.8           6.4           2.0
# 1             7.7           2.6           6.9           2.3
# 2             7.7           3.8           6.7           2.2
# 3             7.7           2.8           6.7           2.0
# 4             7.7           3.0           6.1           2.3
# ..            ...           ...           ...           ...
# 145           4.5           2.3           1.3           0.3
# 146           4.4           2.9           1.4           0.2
# 147           4.4           3.0           1.3           0.2
# 148           4.4           3.2           1.3           0.2
# 149           4.3           3.0           1.1           0.1
#
# [150 rows x 4 columns]

# %%
# Si la fila/columna no existe, nos dará error

df.drop("Flor", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Ane Zubieta\Documents\datascienceandia\mod3-data-science\1.Numpy_pandas\02.pandas_series.ipynb Celda 55 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Ane%20Zubieta/Documents/datascienceandia/mod3-data-science/1.Numpy_pandas/02.pandas_series.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> # Si la fila/columna no existe, nos dará error
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ane%20Zubieta/Documents/datascienceandia/mod3-data-science/1.Numpy_pandas/02.pandas_series.ipynb#Y104sZmlsZQ%3D%3D?line=2'>3</a> df.drop("Flor", axis = 1)
#
# File c:\Users\Ane Zubieta\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Ane Zubieta\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File c:\Users\Ane Zubieta\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File c:\Users\Ane Zubieta\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File c:\Users\Ane Zubieta\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Flor'] not found in axis"

# %%
df["Clase2"] = df["Clase"]

df.head(3)
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0           7.9           3.8           6.4           2.0  Iris-virginica
# 1           7.7           2.6           6.9           2.3  Iris-virginica
# 2           7.7           3.8           6.7           2.2  Iris-virginica
#
#            Clase2
# 0  Iris-virginica
# 1  Iris-virginica
# 2  Iris-virginica

# %%
# Si queremos que la operación sea in-place podemos agregar el parametro

df.drop("Clase2", axis = 1, inplace = True)

# %%
df.head(3)
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0           7.9           3.8           6.4           2.0  Iris-virginica
# 1           7.7           2.6           6.9           2.3  Iris-virginica
# 2           7.7           3.8           6.7           2.2  Iris-virginica

# %%
# Si queremos agregar una fila #PROXIMAMENTE APPEND = .CONCAT

df = df.append({"Largo Sepalo" : 0, "Ancho Sepalo" : 0, "Largo Petalo" : 0, "Ancho Petalo" : 0, "Clase" : "Nueva-Flor"},
               ignore_index = True)
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\3061077841.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Largo Sepalo" : 0, "Ancho Sepalo" : 0, "Largo Petalo" : 0, "Ancho Petalo" : 0, "Clase" : "Nueva-Flor"},

# %%
df = df.append({"Largo Sepalo" : 3000, "Ancho Sepalo" : 40, "Largo Petalo" : 20, "Ancho Petalo" : 50, "Clase" : "Flor"},
               ignore_index = True)
# Out:
# C:\Users\Ane Zubieta\AppData\Local\Temp\ipykernel_12648\3097993671.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Largo Sepalo" : 3000, "Ancho Sepalo" : 40, "Largo Petalo" : 20, "Ancho Petalo" : 50, "Clase" : "Flor"},

# %%
df.tail()
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 147           4.4           3.0           1.3           0.2  Iris-setosa
# 148           4.4           3.2           1.3           0.2  Iris-setosa
# 149           4.3           3.0           1.1           0.1  Iris-setosa
# 150           0.0           0.0           0.0           0.0   Nueva-Flor
# 151        3000.0          40.0          20.0          50.0         Flor

# %%
# .value_counts() Se usa para contar los valores únicos de las columnas (Series)

df["Clase"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Nueva-Flor          1
# Flor                1
# Name: Clase, dtype: int64

# %%
# Podemos "Normalizar" el resultado

df["Clase"].value_counts(normalize = True)
# Out:
# Iris-virginica     0.328947
# Iris-versicolor    0.328947
# Iris-setosa        0.328947
# Nueva-Flor         0.006579
# Flor               0.006579
# Name: Clase, dtype: float64

# %%
# .unique() retorna un array con los valores únicos de las columnas
df["Clase"].unique()
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Nueva-Flor',
#        'Flor'], dtype=object)

# %% [markdown]
# ### Filtros

# %%
# Para aplicar un filtro usamos los operadores de comparación

df["Largo Sepalo"] > 7
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 147    False
# 148    False
# 149    False
# 150    False
# 151     True
# Name: Largo Sepalo, Length: 152, dtype: bool

# %%
# Esto retorna una Serie con Verdaderos y Falsos
# Si quisieramos aplicar ese filtro al DataFrame hariamos un "indexing" con el operador

df[df["Largo Sepalo"] > 7]

# Esto nos retorna el DataFrame solo con las filas que cumplen la condición
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             7.9           3.8           6.4           2.0  Iris-virginica
# 1             7.7           2.6           6.9           2.3  Iris-virginica
# 2             7.7           3.8           6.7           2.2  Iris-virginica
# 3             7.7           2.8           6.7           2.0  Iris-virginica
# 4             7.7           3.0           6.1           2.3  Iris-virginica
# 5             7.6           3.0           6.6           2.1  Iris-virginica
# 6             7.4           2.8           6.1           1.9  Iris-virginica
# 7             7.3           2.9           6.3           1.8  Iris-virginica
# 8             7.2           3.6           6.1           2.5  Iris-virginica
# 9             7.2           3.2           6.0           1.8  Iris-virginica
# 10            7.2           3.0           5.8           1.6  Iris-virginica
# 11            7.1           3.0           5.9           2.1  Iris-virginica
# 151        3000.0          40.0          20.0          50.0            Flor

# %%
df[(df["Largo Sepalo"] > 7) | (df["Ancho Petalo"] < 2)]
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             7.9           3.8           6.4           2.0  Iris-virginica
# 1             7.7           2.6           6.9           2.3  Iris-virginica
# 2             7.7           3.8           6.7           2.2  Iris-virginica
# 3             7.7           2.8           6.7           2.0  Iris-virginica
# 4             7.7           3.0           6.1           2.3  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 147           4.4           3.0           1.3           0.2     Iris-setosa
# 148           4.4           3.2           1.3           0.2     Iris-setosa
# 149           4.3           3.0           1.1           0.1     Iris-setosa
# 150           0.0           0.0           0.0           0.0      Nueva-Flor
# 151        3000.0          40.0          20.0          50.0            Flor
#
# [131 rows x 5 columns]

# %% [markdown]
# Para aplicar más de un filtro debemos usar los operadores **`&`** y **`|`** y agrupar las condición en parentesis **`()`**.

# %%
df[(df["Largo Sepalo"] > 7) & (df["Ancho Petalo"] == 2)]
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0           7.9           3.8           6.4           2.0  Iris-virginica
# 3           7.7           2.8           6.7           2.0  Iris-virginica

# %%
df[(df["Clase"] == "Iris-virginica") | (df["Clase"] == "Iris-versicolor")]
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo            Clase
# 0             7.9           3.8           6.4           2.0   Iris-virginica
# 1             7.7           2.6           6.9           2.3   Iris-virginica
# 2             7.7           3.8           6.7           2.2   Iris-virginica
# 3             7.7           2.8           6.7           2.0   Iris-virginica
# 4             7.7           3.0           6.1           2.3   Iris-virginica
# ..            ...           ...           ...           ...              ...
# 110           5.1           2.5           3.0           1.1  Iris-versicolor
# 118           5.0           2.0           3.5           1.0  Iris-versicolor
# 119           5.0           2.3           3.3           1.0  Iris-versicolor
# 128           4.9           2.5           4.5           1.7   Iris-virginica
# 129           4.9           2.4           3.3           1.0  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
################################################################################################################################
